# %%
import pandas as pd

from ccsblib import paros_connection

# %%
#qry = """select *
#from tf_validation.validation_cp
#where standard_batch = 'TFv02';"""
qry = """
select a.*, b.source
from tf_validation.validation_cp as a
left join tf_validation.validation_source as b
on a.standard_batch = b.standard_batch
and a.test_orf_ida = b.orf_id2
and a.test_orf_idb = b.orf_id1
where a.standard_batch = 'TFv02';
"""
df = pd.read_sql(qry, paros_connection())
missing = pd.read_excel('TFv02_empty_wells_after_cp.xlsx', sheet_name='Empty destination wells')
missing['Destination_plate'] = missing['Destination_plate'].str.slice(0, -3)
missing['Destination_well'] = missing['Destination_well'].apply(lambda x: x[0] + str(x[1:]).zfill(2))

# %%
missing.shape
# Out:
# (47, 5)

# %%
df = pd.merge(df, missing, how='inner',
         left_on=['test_pla_full', 'test_pos'],
         right_on=['Destination_plate', 'Destination_well'])
df
# Out:
#       id  test_orf_ida  test_orf_idb standard_batch experiment_batch assay  \
# 0   5412         10051        100448          TFv02             None  None
# 1   5415         12504        101244          TFv02             None  None
# 2   5468         71077        101171          TFv02             None  None
# 3   5480     100016074        101171          TFv02             None  None
# 4   5532             0        100247          TFv02             None  None
# 5   5559             0        101222          TFv02             None  None
# 6   5566         10051        100645          TFv02             None  None
# 7   5567         10051             0          TFv02             None  None
# 8   5616         11179        100247          TFv02             None  None
# 9   5618         11179        100178          TFv02             None  None
# 10  5653     100069883        100315          TFv02             None  None
# 11  5655          6119        100315          TFv02             None  None
# 12  5672             0        100568          TFv02             None  None
# 13  5674     100069883        100568          TFv02             None  None
# 14  5691         10051             0          TFv02             None  None
# 15  5740             0        101390          TFv02             None  None
# 16  5755         11965        100801          TFv02             None  None
# 17  5786          3198        101390          TFv02             None  None
# 18  5797          6440        100313          TFv02             None  None
# 19  5798             0        100313          TFv02             None  None
# 20  5807         14023        100178          TFv02             None  None
# 21  5824             0        100565          TFv02             None  None
# 22  5847         13577        100703          TFv02             None  None
# 23  5848             0        100703          TFv02             None  None
# 24  5858          6636        100703          TFv02             None  None
# 25  5860     100009829        100703          TFv02             None  None
# 26  5860     100009829        100703          TFv02             None  None
# 27  5873     100009829        100313          TFv02             None  None
# 28  5881          8787        100247          TFv02             None  None
# 29  5883     100009829        100247          TFv02             None  None
# 30  5927          8273        100565          TFv02             None  None
# 31  5958         53279        101369          TFv02             None  None
# 32  5964         53158        100178          TFv02             None  None
# 33  5990             0        100313          TFv02             None  None
# 34  5993          7673        100247          TFv02             None  None
# 35  6010          3522        100455          TFv02             None  None
# 36  6011             0        100455          TFv02             None  None
# 37  6021             0        101070          TFv02             None  None
# 38  6022          6725        100801          TFv02             None  None
# 39  6024         55423        100247          TFv02             None  None
# 40  6066         11435        100703          TFv02             None  None
# 41  6068             0        100703          TFv02             None  None
# 42  6071         13318        100565          TFv02             None  None
# 43  6073             0        100565          TFv02             None  None
# 44  6078          4144        101222          TFv02             None  None
# 45  6203          5442        100455          TFv02             None  None
# 46  6277           604        100455          TFv02             None  None
#
#    control  test_pla test_pos test_pla_full  ... orf_ida_source_plate  \
# 0     None         1      D09  TFv02N2H_001  ...      TFv02_N1N2_Hub1
# 1     None         1      D12  TFv02N2H_001  ...      TFv02R2N1_005_w
# 2     None         2      A12  TFv02N2H_002  ...      TFv02R2N1_006_w
# 3     None         2      B12  TFv02N2H_002  ...      TFv02R2N1_002_w
# 4     None         2      G04  TFv02N2H_002  ...           mN2H_F1_F2
# 5     None         3      A12  TFv02N2H_003  ...           mN2H_F1_F2
# 6     None         3      B07  TFv02N2H_003  ...      TFv02_N1N2_Hub1
# 7     None         3      B08  TFv02N2H_003  ...      TFv02_N1N2_Hub1
# 8     None         3      F09  TFv02N2H_003  ...      TFv02R2N1_002_w
# 9     None         3      F11  TFv02N2H_003  ...      TFv02R2N1_002_w
# 10    None         4      B10  TFv02N2H_004  ...     TFv02LowDNA_N1N2
# 11    None         4      B12  TFv02N2H_004  ...      TFv02R2N1_002_w
# 12    None         4      D05  TFv02N2H_004  ...           mN2H_F1_F2
# 13    None         4      D07  TFv02N2H_004  ...     TFv02LowDNA_N1N2
# 14    None         4      E12  TFv02N2H_004  ...      TFv02_N1N2_Hub1
# 15    None         5      B05  TFv02N2H_005  ...           mN2H_F1_F2
# 16    None         5      C08  TFv02N2H_005  ...      TFv02R2N1_003_w
# 17    None         5      F03  TFv02N2H_005  ...      TFv02R2N1_004_w
# 18    None         5      G02  TFv02N2H_005  ...      TFv02R2N1_005_w
# 19    None         5      G03  TFv02N2H_005  ...           mN2H_F1_F2
# 20    None         5      H01  TFv02N2H_005  ...      TFv02R2N1_005_w
# 21    None         6      A11  TFv02N2H_006  ...           mN2H_F1_F2
# 22    None         6      C10  TFv02N2H_006  ...      TFv02R2N1_002_w
# 23    None         6      C11  TFv02N2H_006  ...           mN2H_F1_F2
# 24    None         6      D09  TFv02N2H_006  ...      TFv02R2N1_005_w
# 25    None         6      D11  TFv02N2H_006  ...     TFv02LowDNA_N1N2
# 26    None         6      D11  TFv02N2H_006  ...     TFv02LowDNA_N1N2
# 27    None         6      E12  TFv02N2H_006  ...     TFv02LowDNA_N1N2
# 28    None         6      F08  TFv02N2H_006  ...      TFv02R2N1_001_w
# 29    None         6      F10  TFv02N2H_006  ...     TFv02LowDNA_N1N2
# 30    None         7      B11  TFv02N2H_007  ...      TFv02R2N1_005_w
# 31    None         7      E06  TFv02N2H_007  ...      TFv02R2N1_003_w
# 32    None         7      E12  TFv02N2H_007  ...      TFv02R2N1_005_w
# 33    None         8      A03  TFv02N2H_008  ...           mN2H_F1_F2
# 34    None         8      A06  TFv02N2H_008  ...      TFv02R2N1_003_w
# 35    None         8      B11  TFv02N2H_008  ...      TFv02R2N1_004_w
# 36    None         8      B12  TFv02N2H_008  ...           mN2H_F1_F2
# 37    None         8      C10  TFv02N2H_008  ...           mN2H_F1_F2
# 38    None         8      C11  TFv02N2H_008  ...      TFv02R2N1_004_w
# 39    None         8      D01  TFv02N2H_008  ...      TFv02R2N1_004_w
# 40    None         9      A04  TFv02N2H_009  ...      TFv02R2N1_003_w
# 41    None         9      A06  TFv02N2H_009  ...           mN2H_F1_F2
# 42    None         9      A09  TFv02N2H_009  ...      TFv02R2N1_004_w
# 43    None         9      A11  TFv02N2H_009  ...           mN2H_F1_F2
# 44    None         9      B04  TFv02N2H_009  ...      TFv02R2N1_004_w
# 45    None        10      E08  TFv02N2H_010  ...      TFv02R2N1_004_w
# 46    None        11      E01  TFv02N2H_011  ...      TFv02R2N1_001_w
#
#     orf_ida_source_well  orf_idb_source_plate orf_idb_source_well  \
# 0                   A01       TFv02R2N2_004_w                 F10
# 1                   H07       TFv02R2N2_004_w                 A07
# 2                   E08       TFv02_N1N2_Hub1                 C01
# 3                   G10       TFv02_N1N2_Hub1                 C01
# 4                   A01       TFv02_N1N2_Hub1                 F02
# 5                   A01       TFv02_N1N2_Hub1                 H03
# 6                   A01       TFv02R2N2_004_w                 D07
# 7                   A01            mN2H_F1_F2                 F01
# 8                   E04       TFv02_N1N2_Hub1                 F02
# 9                   E04       TFv02_N1N2_Hub1                 C02
# 10                  B03       TFv02_N1N2_Hub1                 H04
# 11                  D07       TFv02_N1N2_Hub1                 H04
# 12                  A01       TFv02_N1N2_Hub1                 F04
# 13                  B03       TFv02_N1N2_Hub1                 F04
# 14                  B01            mN2H_F1_F2                 F01
# 15                  A01       TFv02_N1N2_Hub1                 B04
# 16                  H08       TFv02_N1N2_Hub1                 D04
# 17                  G10       TFv02_N1N2_Hub1                 B04
# 18                  E05       TFv02_N1N2_Hub1                 E03
# 19                  A01       TFv02_N1N2_Hub1                 E03
# 20                  H10       TFv02_N1N2_Hub1                 C02
# 21                  A01       TFv02_N1N2_Hub1                 B03
# 22                  G01       TFv02_N1N2_Hub1                 H01
# 23                  A01       TFv02_N1N2_Hub1                 H01
# 24                  D12       TFv02_N1N2_Hub1                 H01
# 25                  E03       TFv02_N1N2_Hub1                 H01
# 26                  E03       TFv02_N1N2_Hub1                 H01
# 27                  E03       TFv02_N1N2_Hub1                 F03
# 28                  G06       TFv02_N1N2_Hub1                 G02
# 29                  E03       TFv02_N1N2_Hub1                 H02
# 30                  E03       TFv02_N1N2_Hub1                 B03
# 31                  F12       TFv02R2N2_005_w                 A03
# 32                  A06       TFv02_N1N2_Hub1                 D02
# 33                  B01       TFv02_N1N2_Hub1                 F03
# 34                  B11       TFv02_N1N2_Hub1                 H02
# 35                  G06       TFv02_N1N2_Hub1                 E01
# 36                  B01       TFv02_N1N2_Hub1                 E01
# 37                  B01       TFv02R2N2_003_w                 F08
# 38                  D12       TFv02_N1N2_Hub1                 D04
# 39                  B01       TFv02_N1N2_Hub1                 H02
# 40                  B08       TFv02_N1N2_Hub1                 A02
# 41                  B01       TFv02_N1N2_Hub1                 A02
# 42                  D11       TFv02_N1N2_Hub1                 C03
# 43                  B01       TFv02_N1N2_Hub1                 C03
# 44                  B11       TFv02_N1N2_Hub1                 H03
# 45                  B04       TFv02_N1N2_Hub1                 F01
# 46                  F07       TFv02_N1N2_Hub1                 F01
#
#                        source Destination_plate Destination_well  \
# 0              whole_tf_genes      TFv02N2H_001              D09
# 1              whole_tf_genes      TFv02N2H_001              D12
# 2   isoform_matched_negatives      TFv02N2H_002              A12
# 3   isoform_matched_negatives      TFv02N2H_002              B12
# 4                        None      TFv02N2H_002              G04
# 5                        None      TFv02N2H_003              A12
# 6           isoform_positives      TFv02N2H_003              B07
# 7                        None      TFv02N2H_003              B08
# 8   isoform_matched_negatives      TFv02N2H_003              F09
# 9   isoform_matched_negatives      TFv02N2H_003              F11
# 10             whole_tf_genes      TFv02N2H_004              B10
# 11             whole_tf_genes      TFv02N2H_004              B12
# 12                       None      TFv02N2H_004              D05
# 13             whole_tf_genes      TFv02N2H_004              D07
# 14                       None      TFv02N2H_004              E12
# 15                       None      TFv02N2H_005              B05
# 16  isoform_matched_negatives      TFv02N2H_005              C08
# 17          isoform_negatives      TFv02N2H_005              F03
# 18          isoform_negatives      TFv02N2H_005              G02
# 19                       None      TFv02N2H_005              G03
# 20          isoform_positives      TFv02N2H_005              H01
# 21                       None      TFv02N2H_006              A11
# 22  isoform_matched_negatives      TFv02N2H_006              C10
# 23                       None      TFv02N2H_006              C11
# 24  isoform_matched_negatives      TFv02N2H_006              D09
# 25  isoform_matched_negatives      TFv02N2H_006              D11
# 26  isoform_matched_negatives      TFv02N2H_006              D11
# 27  isoform_matched_negatives      TFv02N2H_006              E12
# 28          isoform_negatives      TFv02N2H_006              F08
# 29  isoform_matched_negatives      TFv02N2H_006              F10
# 30          isoform_positives      TFv02N2H_007              B11
# 31          isoform_positives      TFv02N2H_007              E06
# 32          isoform_negatives      TFv02N2H_007              E12
# 33                       None      TFv02N2H_008              A03
# 34          isoform_negatives      TFv02N2H_008              A06
# 35          isoform_positives      TFv02N2H_008              B11
# 36                       None      TFv02N2H_008              B12
# 37                       None      TFv02N2H_008              C10
# 38          isoform_negatives      TFv02N2H_008              C11
# 39          isoform_negatives      TFv02N2H_008              D01
# 40          isoform_positives      TFv02N2H_009              A04
# 41                       None      TFv02N2H_009              A06
# 42          isoform_positives      TFv02N2H_009              A09
# 43                       None      TFv02N2H_009              A11
# 44                       None      TFv02N2H_009              B04
# 45          isoform_positives      TFv02N2H_010              E08
# 46                       None      TFv02N2H_011              E01
#
#    Destination_well_number      Source_plate Source_well_number
# 0                       68   TFv02_N1N2_Hub1                  1
# 1                       92   TFv02R2N1_005_w                 56
# 2                       89   TFv02_N1N2_Hub1                  3
# 3                       90   TFv02_N1N2_Hub1                  3
# 4                       31   TFv02_N1N2_Hub1                 14
# 5                       89   TFv02_N1N2_Hub1                 24
# 6                       50   TFv02_N1N2_Hub1                  1
# 7                       58   TFv02_N1N2_Hub1                  1
# 8                       70   TFv02_N1N2_Hub1                 14
# 9                       86   TFv02_N1N2_Hub1                 11
# 10                      74   TFv02_N1N2_Hub1                 32
# 11                      90   TFv02_N1N2_Hub1                 32
# 12                      36   TFv02_N1N2_Hub1                 30
# 13                      52   TFv02_N1N2_Hub1                 30
# 14                      93   TFv02_N1N2_Hub1                  2
# 15                      34   TFv02_N1N2_Hub1                 26
# 16                      59   TFv02_N1N2_Hub1                 28
# 17                      22   TFv02_N1N2_Hub1                 26
# 18                      15   TFv02_N1N2_Hub1                 21
# 19                      23   TFv02_N1N2_Hub1                 21
# 20                       8   TFv02_N1N2_Hub1                 11
# 21                      81   TFv02_N1N2_Hub1                 18
# 22                      75   TFv02R2N1_002_w                  7
# 23                      83   TFv02_N1N2_Hub1                  8
# 24                      68   TFv02R2N1_005_w                 92
# 25                      84  TFv02LowDNA_N1N2                 21
# 26                      84   TFv02_N1N2_Hub1                  8
# 27                      93  TFv02LowDNA_N1N2                 21
# 28                      62   TFv02_N1N2_Hub1                 15
# 29                      78  TFv02LowDNA_N1N2                 21
# 30                      82   TFv02_N1N2_Hub1                 18
# 31                      45   TFv02R2N2_005_w                 17
# 32                      93   TFv02_N1N2_Hub1                 12
# 33                      17   TFv02_N1N2_Hub1                 22
# 34                      41   TFv02_N1N2_Hub1                 16
# 35                      82   TFv02_N1N2_Hub1                  5
# 36                      90   TFv02_N1N2_Hub1                  5
# 37                      75   TFv02R2N2_003_w                 62
# 38                      83   TFv02_N1N2_Hub1                 28
# 39                       4   TFv02_N1N2_Hub1                 16
# 40                      25   TFv02_N1N2_Hub1                  9
# 41                      41   TFv02_N1N2_Hub1                  9
# 42                      65   TFv02_N1N2_Hub1                 19
# 43                      81   TFv02_N1N2_Hub1                 19
# 44                      26   TFv02_N1N2_Hub1                 24
# 45                      61   TFv02_N1N2_Hub1                  6
# 46                       5   TFv02_N1N2_Hub1                  6
#
# [47 rows x 23 columns]

# %%
df['source'].value_counts(dropna=False)
# Out:
# NaN                          16
# isoform_matched_negatives    11
# isoform_positives             8
# isoform_negatives             7
# whole_tf_genes                5
# Name: source, dtype: int64

# %%
df.loc[df['source'].isnull(), ['test_orf_ida', 'test_orf_idb', 'test_pla', 'test_pos']].sort_values(['test_orf_ida', 'test_orf_idb'])
# Out:
#     test_orf_ida  test_orf_idb  test_pla test_pos
# 4              0        100247         2      G04
# 19             0        100313         5      G03
# 33             0        100313         8      A03
# 36             0        100455         8      B12
# 21             0        100565         6      A11
# 43             0        100565         9      A11
# 12             0        100568         4      D05
# 23             0        100703         6      C11
# 41             0        100703         9      A06
# 37             0        101070         8      C10
# 5              0        101222         3      A12
# 15             0        101390         5      B05
# 46           604        100455        11      E01
# 44          4144        101222         9      B04
# 7          10051             0         3      B08
# 14         10051             0         4      E12

# %%
# two questions for the controls
    #1 how many pairs on the plate does it compromise?
    #2 does the control exist on another plate?
qry = """
select a.test_orf_ida, a.test_orf_idb, a.test_pla, a.test_pos, a.test_pla_full, b.source
from tf_validation.validation_cp as a
left join tf_validation.validation_source as b
on a.standard_batch = b.standard_batch
and a.test_orf_ida = b.orf_id2
and a.test_orf_idb = b.orf_id1
where a.standard_batch = 'TFv02';
"""
full = pd.read_sql(qry, paros_connection())

# %%
full.head()
# Out:
#    test_orf_ida  test_orf_idb  test_pla test_pos test_pla_full          source
# 0         54731        101256         1      A01  TFv02N2H_001  whole_tf_genes
# 1         54731             0         1      A02  TFv02N2H_001            None
# 2             0        101256         1      A03  TFv02N2H_001            None
# 3         12504        101256         1      A04  TFv02N2H_001  whole_tf_genes
# 4         12504             0         1      A05  TFv02N2H_001            None

# %%
void = []
for _i, row in df.loc[(df['test_orf_ida'] == 0) | (df['test_orf_idb'] == 0), :].iterrows():
    if row['test_orf_ida'] == 0:
        void.append(full.loc[(full['test_orf_idb'] == row['test_orf_idb'])
                              & (full['test_pla'] == row['test_pla'])])
    else:
        void.append(full.loc[(full['test_orf_ida'] == row['test_orf_ida'])
                              & (full['test_pla'] == row['test_pla'])])
void = pd.concat(void)
void
# Out:
#      test_orf_ida  test_orf_idb  test_pla test_pos test_pla_full  \
# 169           120        100247         2      G03  TFv02N2H_002
# 170             0        100247         2      G04  TFv02N2H_002
# 179         53326        100247         2      H02  TFv02N2H_002
# 196          5424        101222         3      A11  TFv02N2H_003
# 197             0        101222         3      A12  TFv02N2H_003
# 224     100066358        101222         3      D03  TFv02N2H_003
# 226          1136        101222         3      D05  TFv02N2H_003
# 227           842        101222         3      D06  TFv02N2H_003
# 229          1618        101222         3      D08  TFv02N2H_003
# 204         10051        100645         3      B07  TFv02N2H_003
# 205         10051             0         3      B08  TFv02N2H_003
# 207         10051        100633         3      B10  TFv02N2H_003
# 208         10051        101218         3      B11  TFv02N2H_003
# 209         10051        100810         3      B12  TFv02N2H_003
# 315          6119        100568         4      D04  TFv02N2H_004
# 316             0        100568         4      D05  TFv02N2H_004
# 318     100069883        100568         4      D07  TFv02N2H_004
# 334         10051        100769         4      E11  TFv02N2H_004
# 335         10051             0         4      E12  TFv02N2H_004
# 349         10051        100340         4      G02  TFv02N2H_004
# 351         10051        100786         4      G04  TFv02N2H_004
# 383         52628        101390         5      B04  TFv02N2H_005
# 384             0        101390         5      B05  TFv02N2H_005
# 429         14887        101390         5      F01  TFv02N2H_005
# 430          5002        101390         5      F02  TFv02N2H_005
# 431          3198        101390         5      F03  TFv02N2H_005
# 442          6440        100313         5      G02  TFv02N2H_005
# 443             0        100313         5      G03  TFv02N2H_005
# 468         13474        100565         6      A09  TFv02N2H_006
# 470             0        100565         6      A11  TFv02N2H_006
# 471          6636        100565         6      A12  TFv02N2H_006
# 474         53886        100565         6      B03  TFv02N2H_006
# 476     100009829        100565         6      B05  TFv02N2H_006
# 493         13577        100703         6      C10  TFv02N2H_006
# 494             0        100703         6      C11  TFv02N2H_006
# 501         13474        100703         6      D06  TFv02N2H_006
# 504          6636        100703         6      D09  TFv02N2H_006
# 505         10057        100703         6      D10  TFv02N2H_006
# 506     100009829        100703         6      D11  TFv02N2H_006
# 636         14681        100313         8      A01  TFv02N2H_008
# 638             0        100313         8      A03  TFv02N2H_008
# 653         54463        100313         8      B06  TFv02N2H_008
# 654         52740        100313         8      B07  TFv02N2H_008
# 656          3522        100313         8      B09  TFv02N2H_008
# 691          5224        100313         8      E08  TFv02N2H_008
# 658          3522        100455         8      B11  TFv02N2H_008
# 659             0        100455         8      B12  TFv02N2H_008
# 663         54271        100455         8      C04  TFv02N2H_008
# 707          4920        100455         8      F12  TFv02N2H_008
# 667          6725        101070         8      C08  TFv02N2H_008
# 669             0        101070         8      C10  TFv02N2H_008
# 714         11435        100703         9      A04  TFv02N2H_009
# 716             0        100703         9      A06  TFv02N2H_009
# 717          3753        100703         9      A07  TFv02N2H_009
# 719         13318        100565         9      A09  TFv02N2H_009
# 721             0        100565         9      A11  TFv02N2H_009
# 742          7225        100565         9      C08  TFv02N2H_009
# 751          4929        100565         9      D05  TFv02N2H_009
#
#                         source
# 169  isoform_matched_negatives
# 170                       None
# 179  isoform_matched_negatives
# 196             whole_tf_genes
# 197                       None
# 224             whole_tf_genes
# 226             whole_tf_genes
# 227             whole_tf_genes
# 229             whole_tf_genes
# 204          isoform_positives
# 205                       None
# 207          isoform_positives
# 208  isoform_matched_negatives
# 209  isoform_matched_negatives
# 315             whole_tf_genes
# 316                       None
# 318             whole_tf_genes
# 334             whole_tf_genes
# 335                       None
# 349             whole_tf_genes
# 351             whole_tf_genes
# 383  isoform_matched_negatives
# 384                       None
# 429  isoform_matched_negatives
# 430  isoform_matched_negatives
# 431          isoform_negatives
# 442          isoform_negatives
# 443                       None
# 468          isoform_positives
# 470                       None
# 471  isoform_matched_negatives
# 474          isoform_positives
# 476          isoform_positives
# 493  isoform_matched_negatives
# 494                       None
# 501  isoform_matched_negatives
# 504  isoform_matched_negatives
# 505          isoform_positives
# 506  isoform_matched_negatives
# 636          isoform_negatives
# 638                       None
# 653          isoform_negatives
# 654          isoform_negatives
# 656          isoform_positives
# 691          isoform_negatives
# 658          isoform_positives
# 659                       None
# 663          isoform_positives
# 707          isoform_positives
# 667          isoform_positives
# 669                       None
# 714          isoform_positives
# 716                       None
# 717          isoform_positives
# 719          isoform_positives
# 721                       None
# 742          isoform_positives
# 751          isoform_positives

# %%
# note: could be some overlap with missing pairs
void['source'].value_counts()
# Out:
# isoform_positives            16
# isoform_matched_negatives    12
# whole_tf_genes               10
# isoform_negatives             6
# Name: source, dtype: int64

# %%
void = []
for _i, row in df.loc[(df['test_orf_ida'] == 0) | (df['test_orf_idb'] == 0), :].iterrows():
    print(((full['test_orf_ida'] == row['test_orf_ida']) &
          (full['test_orf_idb'] == row['test_orf_idb']) &
          (full['test_pla'] != row['test_pla'])).sum())
# Out:
# 8
# 3
# 2
# 4
# 2
# 4
# 7
# 6
# 5
# 7
# 5
# 3
# 5
# 6

# %% [markdown]
# To start with we have:
#
# 300 isoform positives
# 294 isoform negatives
#
# we loose 8 positives and 18 negatives
#
# from the controls,
# 16 positives, 18 negatives
