# %% [markdown]
# Looking for expression of differential PPI partners of NFYA in embryonic stem cells
#
# EAF1, NRF1, and PRR20D
#
# data from PCBC 2016 publication - Salomonis et al. Stem Cell Reports 2016

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df = pd.read_csv('../data/internal/DATASET-PCBC-Kallisto-all.txt', sep='\t')
df.head()
# Out:
#       Ensembl_gene                                         Definition  \
# 0  ENSG00000187223  late cornified envelope 2D [Source:HGNC Symbol...
# 1  ENSG00000110514  MAP-kinase activating death domain [Source:HGN...
# 2  ENSG00000086015  microtubule associated serine/threonine kinase...
# 3  ENSG00000197891  solute carrier family 22 (organic anion/urate ...
# 4  ENSG00000211769  T cell receptor beta joining 2-5 [Source:HGNC ...
#
#      Symbol  Transcript_cluster_ids  Constitutive_exons_used  \
# 0     LCE2D                     NaN                      NaN
# 1      MADD                     NaN                      NaN
# 2     MAST2                     NaN                      NaN
# 3  SLC22A12                     NaN                      NaN
# 4   TRBJ2-5                     NaN                      NaN
#
#    Constitutive_IDs_used                    Putative microRNA binding sites  \
# 0                    NaN  hsa-let-7a(miRanda), hsa-let-7b(miRanda), hsa-...
# ...

# %%
df.loc[df['Symbol'].isin(['NFYA', 'EAF1', 'NRF1', 'PRR20D']),
        ['Symbol', 'avg-EB', 'avg-ECTO', 'avg-HSC', 'avg-MESO']]
# Out:
#        Symbol    avg-EB  avg-ECTO   avg-HSC  avg-MESO
# 5364     NRF1  3.715043  4.146467  4.036698  4.032194
# 9381     EAF1  4.056472  4.398791  4.372222  4.779297
# 18578  PRR20D  0.000000  0.003156  0.000000  0.000000
# 38797    NFYA  5.180988  5.297902  4.624662  4.593042
