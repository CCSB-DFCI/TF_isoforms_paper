# %%
# %load_ext autoreload
# %autoreload 2

import functools

import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

from data_loading import load_annotated_gencode_tfs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tfs = load_annotated_gencode_tfs()
# Out:
# reading from cache

# %%
print(len(tfs), 'TFs')
# Out:
# 1635 TFs

# %%
n_iso = pd.Series({name: len(tf.orfs) for name, tf in tfs.items()})
n_iso.head()
# Out:
# SKI       1
# PRDM16    4
# TP73      9
# HES3      1
# ZBTB48    1
# dtype: int64

# %%
print(f'TF with most isoforms is {n_iso.idxmax()} with {n_iso.max()} isoforms')
# Out:
# TF with most isoforms is CREM with 25 isoforms

# %%
# add fraction axis on rhs
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(w=6, h=2)
xs = range(1, n_iso.max() + 1)
ax.bar(x=xs, height=[n_iso.value_counts().to_dict().get(x, 0) for x in xs])
ax.set_xticks(xs)
for pos in ['top', 'right', 'bottom']:
    ax.spines[pos].set_visible(False)
ax.xaxis.set_tick_params(length=0)
ax.set_xlabel('Unique protein isoforms per gene')

def num2pct(y):
    return (y / n_iso.shape[0]) * 100

def pct2num(y):
    return (y / 100) * n_iso.shape[0]


ax.set_ylim(0, 800)
ax.set_yticks(range(0, 800, 100), minor=True)
ax.set_ylabel('TF genes')
for pos in ['top', 'right', 'bottom']:
    ax.spines[pos].set_visible(False)
pctax = ax.secondary_yaxis('right', functions=(num2pct, pct2num))
pctax.set_ylabel('')
pctax.set_yticks(range(0, 46, 5), minor=True)
pctax.set_yticklabels([f'{y:.0f}%' for y in pctax.get_yticks()])
fig.savefig('../figures/n-isoforms-per-gene_GENCODE-v30-TFs_hist.pdf',
            bbox_inches='tight')

# %%
tfdb.loc[tfdb['DBD'] == 'Myb/SANT', :]
# Out:
#            Ensembl ID HGNC symbol       DBD  Is TF?  \
# 1540  ENSG00000096401       CDC5L  Myb/SANT    True
# 1543  ENSG00000135164       DMTF1  Myb/SANT    True
# 1552  ENSG00000170903     MSANTD4  Myb/SANT    True
# 1553  ENSG00000118513         MYB  Myb/SANT    True
# 1554  ENSG00000185697       MYBL1  Myb/SANT    True
# 1555  ENSG00000101057       MYBL2  Myb/SANT    True
# 1556  ENSG00000176182       MYPOP  Myb/SANT    True
# 1557  ENSG00000162601       MYSM1  Myb/SANT    True
# 1568  ENSG00000165684      SNAPC4  Myb/SANT    True
# 1571  ENSG00000249961       TERB1  Myb/SANT    True
# 1572  ENSG00000147601       TERF1  Myb/SANT    True
# 1573  ENSG00000132604       TERF2  Myb/SANT    True
# 1575  ENSG00000125482        TTF1  Myb/SANT    True
# 1576  ENSG00000036549        ZZZ3  Myb/SANT    True
#
#                           TF assessment                         Binding mode  \
# 1540                        Known motif              Monomer or homomultimer
# 1543  Likely to be sequence specific TF              Monomer or homomultimer
# 1552  Likely to be sequence specific TF  Low specificity DNA-binding protein
# 1553                        Known motif              Monomer or homomultimer
# 1554                        Known motif              Monomer or homomultimer
# 1555                        Known motif              Monomer or homomultimer
# 1556  Likely to be sequence specific TF              Monomer or homomultimer
# 1557  Likely to be sequence specific TF  Low specificity DNA-binding protein
# 1568  Likely to be sequence specific TF              Monomer or homomultimer
# 1571  Likely to be sequence specific TF              Monomer or homomultimer
# 1572  Likely to be sequence specific TF              Monomer or homomultimer
# 1573                     Inferred motif              Monomer or homomultimer
# 1575  Likely to be sequence specific TF              Monomer or homomultimer
# 1576                        Known motif              Monomer or homomultimer
#
#                   Motif status  \
# 1540       In vivo/Misc source
# 1543                  No motif
# 1552                  No motif
# 1553       In vivo/Misc source
# 1554  High-throughput in vitro
# 1555  High-throughput in vitro
# 1556                  No motif
# 1557                  No motif
# 1568                  No motif
# 1571                  No motif
# 1572                  No motif
# 1573  High-throughput in vitro
# 1575                  No motif
# 1576  High-throughput in vitro
#
#                                             Final Notes  \
# 1540  Only known motifs are from Transfac or HocoMoc...
# 1543                                                NaN
# 1552                                                NaN
# 1553  Only known motifs are from Transfac or HocoMoc...
# 1554                                                NaN
# 1555                                                NaN
# 1556                                                NaN
# 1557                                                NaN
# 1568                                                NaN
# 1571                                                NaN
# 1572                                                NaN
# 1573                                                NaN
# 1575                                                NaN
# 1576                                                NaN
#
#                                          Final Comments  \
# 1540  Compelling evidence for DNA binding (PMID: 110...
# 1543  Contains 2 Myb DBDs. Binds to CCCG(G/T)ATGT (P...
# 1552  Contains a single Myb-like domain with an inse...
# 1553                                Contains 3 Myb DBDs
# 1554                                Contains 3 Myb DBDs
# 1555                                Contains 3 Myb DBDs
# 1556  Contains a single Myb-like domain. Mouse ortho...
# 1557  MYSM1 has been shown to bind DNA. This interac...
# 1568  EMSA data available showing it can specificall...
# 1571  Contains a single Myb domain (with slightly le...
# 1572  Contains 1 Myb domain, and has structural evid...
# 1573  The sequence in the crystal structure (PDB:1VF...
# 1575  Contains Myb and Myb-like domains, and is anno...
# 1576                                 Contains 1 Myb DBD
#
#                                          Interpro ID(s) EntrezGene ID  \
# 1540            IPR001005;IPR009057;IPR017930;IPR021786           988
# 1543            IPR001005;IPR009057;IPR017877;IPR017930          9988
# 1552                                          IPR028002         84437
# 1553  IPR001005;IPR009057;IPR012642;IPR015395;IPR017...          4602
# 1554  IPR001005;IPR009057;IPR012642;IPR015395;IPR017...          4603
# 1555  IPR001005;IPR009057;IPR015395;IPR017877;IPR017...          4605
# 1556                     IPR001005;IPR017877;IPR028002;        339344
# 1557  IPR000555;IPR001005;IPR007526;IPR009057;IPR017...        114803
# 1568            IPR001005;IPR009057;IPR017877;IPR017930          6621
# 1571                     IPR001005;IPR009057;IPR016024;        283847
# 1572  IPR001005;IPR009057;IPR013867;IPR017357;IPR017...          7013
# 1573  IPR001005;IPR009057;IPR013867;IPR017357;IPR017...          7014
# 1575                                IPR001005;IPR017877          7270
# 1576            IPR000433;IPR001005;IPR009057;IPR017930         26009
#
#                                  EntrezGene Description PDB ID  \
# 1540  cell division cycle 5 like [Source:HGNC Symbol...    NaN
# 1543  cyclin D binding myb like transcription factor...    NaN
# 1552  Myb/SANT DNA binding domain containing 4 with ...    NaN
# 1553  MYB proto-oncogene, transcription factor [Sour...   1MSE
# 1554  MYB proto-oncogene like 1 [Source:HGNC Symbol;...    NaN
# 1555  MYB proto-oncogene like 2 [Source:HGNC Symbol;...    NaN
# 1556  Myb-related transcription factor, partner of p...    NaN
# 1557  Myb like, SWIRM and MPN domains 1 [Source:HGNC...    NaN
# 1568  small nuclear RNA activating complex polypepti...    NaN
# 1571  telomere repeat binding bouquet formation prot...    NaN
# 1572  telomeric repeat binding factor 1 [Source:HGNC...   1IV6
# 1573  telomeric repeat binding factor 2 [Source:HGNC...   1VFC
# 1575  transcription termination factor 1 [Source:HGN...    NaN
# 1576  zinc finger ZZ-type containing 3 [Source:HGNC ...    NaN
#
#      TF tested by HT-SELEX? TF tested by PBM?  \
# 1540           DBD and Full        not tested
# 1543           DBD and Full        not tested
# 1552             not tested        not tested
# 1553           DBD and Full               Yes
# 1554           DBD and Full               Yes
# 1555           DBD and Full               Yes
# 1556             not tested        not tested
# 1557             not tested        not tested
# 1568                    DBD        not tested
# 1571             not tested        not tested
# 1572             not tested               Yes
# 1573                   Full        not tested
# 1575             not tested               Yes
# 1576           DBD and Full               Yes
#
#      Conditional Binding Requirements  Original Comments  \
# 1540                               NaN               NaN
# 1543                               NaN               NaN
# 1552                               NaN               NaN
# 1553                               NaN               NaN
# 1554                               NaN               NaN
# 1555                               NaN               NaN
# 1556                               NaN               NaN
# 1557                               NaN               NaN
# 1568                               NaN               NaN
# 1571                               NaN               NaN
# 1572                               NaN               NaN
# 1573                               NaN               NaN
# 1575                               NaN               NaN
# 1576                               NaN               NaN
#
#      Vaquerizas 2009 classification CisBP considers it a TF?  \
# 1540                              a                      Yes
# 1543                              a                      Yes
# 1552                             No                      Yes
# 1553                              a                      Yes
# 1554                              a                      Yes
# 1555                              a                      Yes
# 1556                              c                       No
# 1557                              c                      Yes
# 1568                              a                      Yes
# 1571                             No                      Yes
# 1572                              c                      Yes
# 1573                              c                      Yes
# 1575                              x                      Yes
# 1576                              b                      Yes
#
#                                    TFCat classification Is a GO TF?  \
# 1540  TF Evidence Conflict - There is evidence for a...         Yes
# 1543  TF Gene_DNA-Binding: sequence-specific_DNA Bin...         Yes
# 1552                                                 No          No
# 1553  TF Gene Candidate_DNA-Binding: sequence-specif...         Yes
# 1554  TF Gene_DNA-Binding: sequence-specific_DNA Bin...         Yes
# 1555  TF Gene Candidate_DNA-Binding: sequence-specif...         Yes
# 1556                                                 No         Yes
# 1557                                                 No          No
# 1568  TF Gene_DNA-Binding: non-sequence-specific; Ba...         Yes
# 1571                                                 No          No
# 1572                                                 No          No
# 1573                                                 No          No
# 1575  TF Gene_DNA-Binding: sequence-specific_DNA Bin...          No
# 1576                                                 No          No
#
#                                     Initial assessment          Curator 1  \
# 1540              2a1, Lower confidence direct evidence  Laura Campitelli
# 1543  3a, decent circumstantial evidence for its rol...      Pratyush Das
# 1552  5a, one of the source datasets predicts is as ...        Yimeng Yin
# 1553                            1a1, Direct HQ evidence        Yimeng Yin
# 1554                            1a1, Direct HQ evidence  Laura Campitelli
# 1555                            1a1, Direct HQ evidence     Matt Weirauch
# 1556                            1a1, Direct HQ evidence      Pratyush Das
# 1557        4a, two or more datasets predict it as a TF       Sam Lambert
# 1568  3a, decent circumstantial evidence for its rol...       Sam Lambert
# 1571  5a, one of the source datasets predicts is as ...       Sam Lambert
# 1572                            1a1, Direct HQ evidence     Matt Weirauch
# 1573                            1a1, Direct HQ evidence       Sam Lambert
# 1575        4a, two or more datasets predict it as a TF     Jussi Taipale
# 1576                            1a1, Direct HQ evidence       Arttu Jolma
#
#              Curator 2 TFclass considers it a TF?   \
# 1540     Matt Weirauch                         Yes
# 1543       Arttu Jolma                         Yes
# 1552  Laura Campitelli                          No
# 1553  Laura Campitelli                         Yes
# 1554       Arttu Jolma                         Yes
# 1555     Jussi Taipale                         Yes
# 1556       Arttu Jolma                          No
# 1557  Laura Campitelli                          No
# 1568     Matt Weirauch                         Yes
# 1571        Yimeng Yin                          No
# 1572  Laura Campitelli                          No
# 1573       Arttu Jolma                          No
# 1575  Laura Campitelli                          No
# 1576     Jussi Taipale                          No
#
#                                             Go Evidence  \
# 1540  $#ENSG00000096401#GO:0000981#sequence-specific...
# 1543  $#ENSG00000135164#GO:0000981#sequence-specific...
# 1552                                                NaN
# 1553  $#ENSG00000118513#GO:0000981#sequence-specific...
# 1554  $#ENSG00000185697#GO:0001077#RNA polymerase II...
# 1555  $#ENSG00000101057#GO:0001077#RNA polymerase II...
# 1556  $#ENSG00000176182#GO:0001078#RNA polymerase II...
# 1557                                                NaN
# 1568  $#ENSG00000165684#GO:0000981#sequence-specific...
# 1571                                                NaN
# 1572                                                NaN
# 1573                                                NaN
# 1575  $#ENSG00000125482#GO:0000981#sequence-specific...
# 1576                                                NaN
#
#                               Pfam Domains (By ENSP ID)
# 1540  $#ENSP00000360532#ENSG00000096401#ENST00000371...
# 1543  $#ENSP00000332171#ENSG00000135164#ENST00000331...
# 1552  $#ENSP00000304713#ENSG00000170903#ENST00000301...
# 1553  $#ENSP00000339992#ENSG00000118513#ENST00000341...
# 1554  $#ENSP00000429633#ENSG00000185697#ENST00000522...
# 1555  $#ENSP00000217026#ENSG00000101057#ENST00000217...
# 1556  $#ENSP00000325402#ENSG00000176182#ENST00000322...
# 1557  $#ENSP00000478391#ENSG00000162601#ENST00000622...
# 1568  $#ENSP00000298532#ENSG00000165684#ENST00000298...
# 1571  $#ENSP00000462482#ENSG00000249961#ENST00000559...
# 1572  $#ENSP00000276602#ENSG00000147601#ENST00000276...
# 1573  $#ENSP00000254942#ENSG00000132604#ENST00000254...
# 1575  $#ENSP00000333920#ENSG00000125482#ENST00000334...
# 1576  $#ENSP00000359834#ENSG00000036549#ENST00000370...

# %%
tfdb['DBD'].value_counts().tail(60)
# Out:
# Forkhead                   49
# Nuclear receptor           46
# HMG/Sox                    30
# Ets                        27
# T-box                      17
# AT hook                    16
# Homeodomain; POU           16
# Myb/SANT                   14
# THAP finger                12
# E2F                        11
# CENPB                      11
# Rel                        10
# BED ZF                     10
# GATA                       10
# SAND                        9
# CxxC                        9
# SMAD                        9
# IRF                         9
# MBD                         8
# HSF                         8
# RFX                         8
# CUT; Homeodomain            7
# DM                          7
# STAT                        7
# MADS box                    6
# Grainyhead                  6
# ARID/BRIGHT                 6
# AP-2                        5
# CSD                         5
# Homeodomain; Paired box     5
# GTF2I-like                  4
# EBF1                        4
# Paired box                  4
# TEA                         4
# C2H2 ZF; Homeodomain        4
# C2H2 ZF; AT hook            4
# mTERF                       4
# CCCH ZF                     3
# Runt                        3
# p53                         3
# TBP                         3
# MADF                        3
# Pipsqueak                   2
# CxxC; AT hook               2
# C2H2 ZF; Myb/SANT           2
# MBD; AT hook                2
# Ndt80/PhoG                  2
# CSL                         2
# Prospero                    2
# C2H2 ZF; BED ZF             2
# GCM                         2
# NFX                         2
# CG-1                        2
# TCR/CxC                     1
# Ets; AT hook                1
# CBF/NF-Y                    1
# FLYWCH                      1
# Brinker                     1
# MBD; CxxC ZF                1
# ARID/BRIGHT; RFX            1
# Name: DBD, dtype: int64

# %%
from data_loading import load_human_tf_db

tfdb = load_human_tf_db()
non_nr_ligand_tfs = {'AHR'} # Hand-curated

fig, ax = plt.subplots(1, 1, sharex=True)
fig.set_size_inches(h=2, w=6)
xs = range(1, df['n_isoforms'].max() + 1)

def num2pct(y, total):
    return (y / total) * 100

def pct2num(y, total):
    return (y / 100) * total

n_iso = df.loc[df['gene'].isin(non_nr_ligand_tfs), 'n_isoforms']
ax.bar(x=xs, height=[n_iso.value_counts().to_dict().get(x, 0) for x in xs])
ax.set_title('Non-nuclear receptor, receptor TFs')
for pos in ['top', 'right']:
    ax.spines[pos].set_visible(False)
ax.xaxis.set_tick_params(length=0)
ax.set_ylabel('Genes')

n = df['gene'].isin(non_nr_ligand_tfs).sum()
pctax = ax.secondary_yaxis('right', 
                            functions=(functools.partial(num2pct, total=n),
                                        functools.partial(pct2num, total=n)))
ax.set_ylim(0, 0.75 * n)
p = min(
    (stats.mannwhitneyu(df.loc[df['gene'].isin(non_nr_ligand_tfs), 'n_isoforms'].values,
                        df.loc[~df['gene'].isin(non_nr_ligand_tfs), 'n_isoforms'].values).pvalue
                        ),
                        1
                        )
ax.text(s=f'mean = {n_iso.mean():.2f} isoforms\np = {p:.2E}',
        x=10,
        y=0.5 * n)
pctax.set_yticks(range(0, 80, 20))
pctax.set_yticks(range(0, 80, 5), minor=True)
pctax.set_yticklabels([f'{y:.0f}%' for y in pctax.get_yticks()])

ax.set_xticks(xs)
ax.set_xlabel('Unique protein isoforms per gene')


fig.savefig('../figures/n-isoforms-per-gene_GENCODE-v30-non-NR-receptor-TFs_hist.pdf',
            bbox_inches='tight')

# %%
print(' '.join(non_nr_ligand_tfs))
# Out:
# NCOA2 NCOA3 NCOA1 LCORL ARNTL2 ARNT2 AHRR NR0B1 ARNTL ARNT AHR LCOR

# %%
tfdb.loc[tfdb['HGNC symbol'] == 'SREBF1']
# Out:
#           Ensembl ID HGNC symbol   DBD  Is TF? TF assessment  \
# 138  ENSG00000072310      SREBF1  bHLH    True   Known motif
#
#                 Binding mode              Motif status Final Notes  \
# 138  Monomer or homomultimer  High-throughput in vitro         NaN
#
#     Final Comments Interpro ID(s) EntrezGene ID  \
# 138            NaN     IPR011598;          6720
#
#                                 EntrezGene Description PDB ID  \
# 138  sterol regulatory element binding transcriptio...   1AM9
#
#     TF tested by HT-SELEX? TF tested by PBM?  \
# 138                    DBD               Yes
#
#     Conditional Binding Requirements   \
# 138                               NaN
#
#                                    Original Comments  \
# 138  Structure is homodimer with the non E-box site
#
#     Vaquerizas 2009 classification CisBP considers it a TF?  \
# 138                              a                      Yes
#
#                                   TFCat classification Is a GO TF?  \
# 138  TF Gene_DNA-Binding: sequence-specific_DNA Bin...         Yes
#
#          Initial assessment       Curator 1      Curator 2  \
# 138  1a1, Direct HQ evidence  Jussi Taipale  Matt Weirauch
#
#     TFclass considers it a TF?   \
# 138                         Yes
#
#                                            Go Evidence  \
# 138  $#ENSG00000072310#GO:0001077#RNA polymerase II...
#
#                              Pfam Domains (By ENSP ID)
# 138  $#ENSP00000261646#ENSG00000072310#ENST00000261...

# %%
# number of isoforms per family
df = pd.DataFrame([(tf.name, len(tf.orfs), tf.tf_family) for name, tf in tfs.items()],
                  columns=['gene', 'n_isoforms', 'family'])
df.head()
# Out:
#      gene  n_isoforms   family
# 0     SKI           1  Unknown
# 1  PRDM16           4  C2H2 ZF
# 2    TP73           9      p53
# 3    HES3           1     bHLH
# 4  ZBTB48           1  C2H2 ZF

# %%
fam_size = df['family'].value_counts()
small_families = set(fam_size[fam_size < 20].index.values)
df['family_merged'] = df['family']
df.loc[df['family'].isin(small_families) | (df['family'] == 'Unknown'), 'family_merged'] = 'other'
df.head()
# Out:
#      gene  n_isoforms   family family_merged
# 0     SKI           1  Unknown         other
# 1  PRDM16           4  C2H2 ZF       C2H2 ZF
# 2    TP73           9      p53         other
# 3    HES3           1     bHLH          bHLH
# 4  ZBTB48           1  C2H2 ZF       C2H2 ZF

# %%
# p-value
# make look nice
families = list(df['family_merged'].value_counts().index.values)
families.remove('other')
families += ['other']

fig, axs = plt.subplots(len(families), 1, sharex=True)
fig.set_size_inches(h=2 * len(families), w=6)
xs = range(1, df['n_isoforms'].max() + 1)

def num2pct(y, total):
    return (y / total) * 100

def pct2num(y, total):
    return (y / 100) * total

for fam, ax in zip(families, axs):
    n_iso = df.loc[df['family_merged'] == fam, 'n_isoforms']
    ax.bar(x=xs, height=[n_iso.value_counts().to_dict().get(x, 0) for x in xs])
    ax.set_title(fam)
    for pos in ['top', 'right']:
        ax.spines[pos].set_visible(False)
    ax.xaxis.set_tick_params(length=0)
    ax.set_ylabel('Genes')

    n = (df['family_merged'] == fam).sum()
    pctax = ax.secondary_yaxis('right', 
                               functions=(functools.partial(num2pct, total=n),
                                          functools.partial(pct2num, total=n)))
    ax.set_ylim(0, 0.75 * n)
    p = min(
        (stats.mannwhitneyu(df.loc[df['family_merged'] == fam, 'n_isoforms'].values,
                           df.loc[df['family_merged'] != fam, 'n_isoforms'].values).pvalue
                           * len(families)
                           ),
                           1
                           )
    ax.text(s=f'mean = {n_iso.mean():.2f} isoforms\np = {p:.2E}',
            x=10,
            y=0.5 * n)
    pctax.set_yticks(range(0, 80, 20))
    pctax.set_yticks(range(0, 80, 5), minor=True)
    pctax.set_yticklabels([f'{y:.0f}%' for y in pctax.get_yticks()])

axs[-1].set_xticks(xs)
axs[-1].set_xlabel('Unique protein isoforms per gene')


fig.savefig('../figures/n-isoforms-per-gene_GENCODE-v30-TFs_by-family_hist.pdf',
            bbox_inches='tight')

# %%
df['n_isoforms'].mean()
# Out:
# 2.5345565749235472

# %%
num2pct['C2H2 ZF'](5)
# Out:
# 1.3089005235602094

# %%
num2pct['Ets'](5)
# Out:
# 1.3089005235602094

# %%
(df['family_merged'] == 'Ets').sum()
# Out:
# 27

# %%
# types of splicing
# including matrix or venn or something...
tfs['ATF2'].exon_diagram()

# %%
tfs['ATF2'].orfs[0]
# Out:
# Isoform: ATF2-201|ATF2-203 / ENSP00000264110|ENSP00000376327 / ENST00000264110|ENST00000392544
# length: 505 aa

# %%
cats = pd.DataFrame([tf.splicing_categories(tf.MANE_select_isoform.name, alt_iso.name) 
              for tf in tfs.values()
              for alt_iso in tf.orfs[1:]
              if tf.has_MANE_select_isoform
              and alt_iso != tf.MANE_select_isoform])

# %%
# check at least one of something

# %%
cats.mean()
# Out:
# alternative N-terminal        0.551370
# alternative C-terminal        0.597260
# alternative internal exon     0.242466
# alternative 5' splice site    0.382877
# alternative 3' splice site    0.471233
# exon skipping                 0.189041
# mutually exclusive exons      0.013014
# intron retention              0.038356
# dtype: float64

# %%
cats.head()
# Out:
#      gene reference isoform alternative isoform  alternative N-terminal  \
# 0  PRDM16        PRDM16-201          PRDM16-206                   False
# 1  PRDM16        PRDM16-201          PRDM16-208                   False
# 2    TP73          TP73-208            TP73-202                   False
# 3    TP73          TP73-208            TP73-204                    True
# 4    TP73          TP73-208            TP73-205                    True
#
#    alternative C-terminal  alternative internal exon  \
# 0                    True                       True
# 1                    True                       True
# 2                    True                       True
# 3                    True                       True
# 4                    True                       True
#
#    alternative 5' splice site  alternative 3' splice site  \
# 0                        True                        True
# 1                        True                        True
# 2                        True                       False
# 3                        True                       False
# 4                        True                       False
#
#    mutually exclusive exons  intron retention strand
# 0                     False             False      +
# 1                     False             False      +
# 2                     False             False      +
# 3                     False             False      +
# 4                     False             False      +

# %%
cats.loc[cats['intron retention']].head()
# Out:
#       gene reference isoform alternative isoform  alternative N-terminal  \
# 107  FOXN2         FOXN2-201           FOXN2-203                    True
# 160  ZC3H8         ZC3H8-201           ZC3H8-208                   False
# 166   ZEB2          ZEB2-204            ZEB2-210                    True
# 169   ZEB2          ZEB2-204            ZEB2-232                   False
# 172  NR4A2         NR4A2-201           NR4A2-203                   False
#
#      alternative C-terminal  alternative internal exon  \
# 107                   False                      False
# 160                    True                      False
# 166                    True                       True
# 169                    True                      False
# 172                    True                      False
#
#      alternative 5' splice site  alternative 3' splice site  \
# 107                        True                        True
# 160                        True                        True
# 166                        True                        True
# 169                        True                        True
# 172                        True                        True
#
#      mutually exclusive exons  intron retention
# 107                     False              True
# 160                     False              True
# 166                     False              True
# 169                     False              True
# 172                     False              True

# %%
# DEBUG
tfs['FOXN2'].exon_diagram()

# %%
cat_cols = cats.columns[3:]
n_cats = cats[cat_cols].sum(axis=1).value_counts().sort_index()
n_cats
# Out:
# 1    304
# 2    587
# 3    237
# 4    240
# 5     72
# 6     20
# dtype: int64

# %%
n_cats / n_cats.sum() * 100
# Out:
# 1    20.821918
# 2    45.273973
# 3    24.383562
# 4     7.602740
# 5     1.917808
# dtype: float64

# %%
cats.groupby(cat_cols)

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(h=2.5, w=3)
(cats.mean() * 100).plot.bar(ax=ax)
ax.set_ylabel('Proportion of alternative\nprotein isoforms')
for pos in ['top', 'right', 'bottom']:
    ax.spines[pos].set_visible(False)
ax.xaxis.set_tick_params(length=0)
ax.set_yticks(range(0, 61, 10))
ax.set_yticklabels(f'{y:d}%' for y in ax.get_yticks())
ax.set_yticks(range(0, int(ax.get_ylim()[1]), 5),
              minor=True)
fig.savefig('../figures/splice-categories_TFs-in-GENCODE-v30_bar.pdf',
            bbox_inches='tight')

# %%
import venn

# %%
import upsetplot


upsetplot.plot(cats.groupby(list(cat_cols)).size())
plt.savefig('../figures/isoform-categories_gencode_UpSet-plot.pdf',
            bbox_inches='tight')

# %%
from data_loading import load_annotated_6k_collection

tfs_cloned = load_annotated_6k_collection()
# Out:
# reading from cache

# %%
df['n_isoforms_cloned'] = (df['gene'].map({tf.name: len(tf.orfs) for tf in tfs_cloned.values()})
                            .fillna(0)
                            .astype(int))

# %%
# p-value
# make look nice
families = list(df['family_merged'].value_counts().index.values)
families.remove('other')
families += ['other']

fig, axs = plt.subplots(len(families), 1, sharex=True)
fig.set_size_inches(h=2 * len(families), w=6)
xs = range(1, df['n_isoforms_cloned'].max() + 1)

def num2pct(y, total):
    return (y / total) * 100

def pct2num(y, total):
    return (y / 100) * total

for fam, ax in zip(families, axs):
    n_iso = df.loc[df['family_merged'] == fam, 'n_isoforms_cloned']
    ax.bar(x=xs, height=[n_iso.value_counts().to_dict().get(x, 0) for x in xs])
    ax.set_title(fam)
    for pos in ['top', 'right']:
        ax.spines[pos].set_visible(False)
    ax.xaxis.set_tick_params(length=0)
    ax.set_ylabel('Genes')

    n = (df.loc[df['n_isoforms_cloned'] >= 1, 'family_merged'] == fam).sum()
    pctax = ax.secondary_yaxis('right', 
                               functions=(functools.partial(num2pct, total=n),
                                          functools.partial(pct2num, total=n)))
    ax.set_ylim(0, 0.75 * n)
    p = min(
        (stats.mannwhitneyu(df.loc[df['family_merged'] == fam, 'n_isoforms_cloned'].values,
                           df.loc[df['family_merged'] != fam, 'n_isoforms_cloned'].values).pvalue
                           * len(families)
                           ),
                           1
                           )
    ax.text(s=f'mean = {n_iso.mean():.2f} isoforms\np = {p:.2E}',
            x=10,
            y=0.5 * n)
    pctax.set_yticks(range(0, 80, 20))
    pctax.set_yticks(range(0, 80, 5), minor=True)
    pctax.set_yticklabels([f'{y:.0f}%' for y in pctax.get_yticks()])

axs[-1].set_xticks(xs)
axs[-1].set_xlabel('Unique protein isoforms per gene')


fig.savefig('../figures/n-isoforms-per-gene_TFiso1-TFs_by-family_hist.pdf',
            bbox_inches='tight')

# %%
# add fraction axis on rhs
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(w=6, h=2)
xs = range(1, df['n_isoforms_cloned'].max() + 1)
ax.bar(x=xs, height=[df['n_isoforms_cloned'].value_counts().to_dict().get(x, 0) for x in xs])
ax.set_xticks(xs)
for pos in ['top', 'right', 'bottom']:
    ax.spines[pos].set_visible(False)
ax.xaxis.set_tick_params(length=0)
ax.set_xlabel('Unique protein isoforms per gene')

def num2pct(y):
    return (y / df['n_isoforms_cloned'].shape[0]) * 100

def pct2num(y):
    return (y / 100) * df['n_isoforms_cloned'].shape[0]


ax.text(s=f'mean = {df["n_isoforms_cloned"].mean():.2f} isoforms',
        x=10,
        y=0.5 * n)

ax.set_ylim(0, 100)
ax.set_yticks(range(0, 100, 10), minor=True)
ax.set_ylabel('TF genes')
for pos in ['top', 'right', 'bottom']:
    ax.spines[pos].set_visible(False)
pctax = ax.secondary_yaxis('right', functions=(num2pct, pct2num))
pctax.set_ylabel('')
pctax.set_yticks(range(0, 46, 5), minor=True)
pctax.set_yticklabels([f'{y:.0f}%' for y in pctax.get_yticks()])
fig.savefig('../figures/n-isoforms-per-gene_TFiso1-TFs_hist.pdf',
            bbox_inches='tight')
