# %%
# test drawing
# %load_ext autoreload
# %autoreload 2
import isolib
test_iso_1 = isolib.Cloned_Isoform('test_iso-1',
                                   [isolib.Exon('test_gene', 'test_iso-1', 'chr1', '+', 11, 41),
                                    isolib.Exon('test_gene', 'test_iso-1', 'chr1', '+', 70, 73),
                                    isolib.Exon('test_gene', 'test_iso-1', 'chr1', '+', 100, 130)],
                                   clone_nt_seq='GGG' * 10 + 'CCC' * 11)
test_iso_2 = isolib.Cloned_Isoform('test_iso-2',
                                   [isolib.Exon('test_gene', 'test_iso-2', 'chr1', '+', 1, 41)],
                                   clone_nt_seq='ATG' * 10 + 'GGG' * 10)
test_iso_1.add_aa_seq_feature('effector_domain', 'test_domain', 'test_domain', 1, 10, description='PMID: 1')
test_gene = isolib.Gene('test_gene', [test_iso_1, test_iso_2])
print(test_iso_1.aa_seq_features[0])
print(test_iso_1.aa_seq_features[0].start, test_iso_1.aa_seq_features[0].end)
test_gene.protein_diagram(draw_vertical_lines_at_domains=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# effector_domain: test_domain test_domain 2-10
# 1 10
# -10

# %%
test_iso_1 = isolib.Cloned_Isoform('test_iso-1',
                                   [isolib.Exon('test_gene', 'test_iso-1', 'chr1', '+', 1, 31),
                                    isolib.Exon('test_gene', 'test_iso-1', 'chr1', '+', 70, 73),
                                    isolib.Exon('test_gene', 'test_iso-1', 'chr1', '+', 100, 130)],
                                   clone_nt_seq='GGG' * 10 + 'CCC' * 11)
test_iso_2 = isolib.Cloned_Isoform('test_iso-2',
                                   [isolib.Exon('test_gene', 'test_iso-2', 'chr1', '+', 1, 31)],
                                   clone_nt_seq='GGG' * 10)
test_iso_1.add_aa_seq_feature('effector_domain', 'test_domain', 'test_domain', 1, 10, description='PMID: 1')
test_gene = isolib.Gene('test_gene', [test_iso_1, test_iso_2])
print(test_iso_1.aa_seq_features[0])
print(test_iso_1.aa_seq_features[0].start, test_iso_1.aa_seq_features[0].end)
test_gene.protein_diagram(draw_vertical_lines_at_domains=True)
# Out:
# effector_domain: test_domain test_domain 2-10
# 1 10
# 0

# %%
test_iso_1 = isolib.Cloned_Isoform('test_iso-1',
                                   [isolib.Exon('test_gene', 'test_iso-1', 'chr1', '+', 1, 31),
                                    isolib.Exon('test_gene', 'test_iso-1', 'chr1', '+', 70, 73),
                                    isolib.Exon('test_gene', 'test_iso-1', 'chr1', '+', 100, 130)],
                                   clone_nt_seq='GGG' * 10 + 'CCC' * 11)
test_iso_2 = isolib.Cloned_Isoform('test_iso-2',
                                   [isolib.Exon('test_gene', 'test_iso-2', 'chr1', '+', 41, 51)],
                                   clone_nt_seq='ATG' * 10)
test_iso_1.add_aa_seq_feature('effector_domain', 'test_domain', 'test_domain', 1, 10, description='PMID: 1')
test_gene = isolib.Gene('test_gene', [test_iso_1, test_iso_2])
print(test_iso_1.aa_seq_features[0])
print(test_iso_1.aa_seq_features[0].start, test_iso_1.aa_seq_features[0].end)
test_gene.protein_diagram(draw_vertical_lines_at_domains=True)
# Out:
# effector_domain: test_domain test_domain 2-10
# 1 10
